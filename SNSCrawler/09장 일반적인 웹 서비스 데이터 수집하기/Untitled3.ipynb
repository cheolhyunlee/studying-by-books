# %%
from selenium import webdriver
wd = webdriver.Chrome('chromedriver')
wd.get('http://www.goobne.co.kr/store/search_store.jsp')
wd.execute_script("store.getList('1')")
html = wd.page_source
print(html)
# Out:
# <!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" lang="ko"><head>
# <!-- Header doc -->
#
#
# <title>굽네치킨</title>
# <meta charset="utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
# <meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1" />
#
# <link rel="shortcut icon" href="/resources/images/favicon.ico" type="image/x-icon" />
# <link rel="icon" href="/resources/images/favicon.ico" type="image/x-icon" />
# <link rel="apple-touch-icon" href="/resources/images/favicon.png" />
#
# <!-- style -->
# <link rel="stylesheet" href="/resources/css/common.css" media="all" />
# <link rel="stylesheet" href="/resources/css/contents.css" media="all" />
# <!--[if lte IE 9]>
# <link rel="stylesheet" href="/resources/css/ie.css" />
#
# <![endif]-->
# <!-- //style -->
#
#
# <!-- javascript -->
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
from itertools import count

def GoobneAddress(result):
    Goobne_URL = 'http://www.goobne.co.kr/store/search_store.jsp'
    wd = webdriver.Chrome('chromedriver')
    wd.get(Goobne_URL)
    time.sleep(5)
    
    for page_idx in count():
        
        wd.execute_script("store.getList('%s')" % str(page_idx + 1))
        print("잘되고 있어")
        
        time.sleep(5)
        
        rcv_data = wd.page_source
        soupData = BeautifulSoup(rcv_data, 'html.parser')
        
        for store_list in soupData.findAll('tbody',attrs = {'id':'store_list'}):
            for store_tr in store_list :
                tr_tag = list(store_tr.strings)
                if (tr_tag[0] == "등록된데이터x"):
                    return result
                
                store_name = tr_tag[1]
                if (tr_tag[3] == ''):
                    store_address = tr_tag[5]
                else :
                    store_address = tr_tag[6]
                    store_sido_gu = store_address.split()[:2]
                    
                result.append([store_name] + store_sido_gu + [store_address])

# %%
result = []

# %%
GoobneAddress(result)
# Out:
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# 잘되고 있어
# ...

# %%
len(result)
# Out:
# 1018

# %%
result[1017]
# Out:
# ['[폐]경북성주점', ' ']

# %%
import pandas as pd
aaa = pd.DataFrame(result, columns = ('store','sido','gungu','store_address'))
aaa.to_csv('goobne.csv',encoding="cp949",mode='w',index=True)
