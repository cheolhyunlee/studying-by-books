# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get('https://pelicana.co.kr/store/stroe_search.html')
c = r.content
soupData = BeautifulSoup(c, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# c:\users\gus26\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# c:\users\gus26\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ...

# %%
soupData = BeautifulSoup(html, 'html.parser')
