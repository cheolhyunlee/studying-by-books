# %%
import numpy as np

# %%
# !pip list
# Out:
# Package              Version
# -------------------- ----------
# absl-py              0.7.0
# astor                0.7.1
# attrs                19.1.0
# backcall             0.1.0
# beautifulsoup4       4.7.1
# bleach               3.1.0
# branca               0.3.1
# bs4                  0.0.1
# certifi              2018.11.29
# chardet              3.0.4
# colorama             0.4.1
# config               0.4.1
# cycler               0.10.0
# decorator            4.3.2
# defusedxml           0.5.0
# descartes            1.1.0
# entrypoints          0.3
# finance-datareader   0.7.2
# folium               0.8.2
# gast                 0.2.2
# glob2                0.6
# googlemaps           3.0.2
# grpcio               1.19.0
# h5py                 2.9.0
# idna                 2.8
# ipykernel            5.1.0
# ipython              7.3.0
# ipython-genutils     0.2.0
# ipywidgets           7.4.2
# jedi                 0.13.3
# Jinja2               2.10
# JPype1               0.6.3
# ...
